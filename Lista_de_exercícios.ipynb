# %% [markdown]
# <a href="https://colab.research.google.com/github/HuelFra/phyton/blob/main/Lista_de_exerc%C3%ADcios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Operações Básicas
# Escreva um programa que receba dois números do usuário e
# exiba o resultado das operações:
# Soma (+)
# Subtração (-)
# Multiplicação (*)
# Divisão (/)
# Divisão inteira (//)
# Módulo (%)
# Exponenciação (**)
n1 =  float(input("Digite o primeiro número: "))
n2 =  float(input("Digite o segundo número: "))
print("***************************************************************")
print ("A soma de n1 + n2 é: ",int(n1 + n2))
print ("A subtração de n1 - n2 é: ",int (n1 - n2))
print ("A multiplicação de n1 * n2 é: ",int(n1 * n2))
print ("A divisão de n1/n2 é: ", n1 / n2)
print ("A divisão interia de n1 // n2 é: ",int(n1 // n2))
print ("O módulo de n1 # n2 é: ",int(n1 % n2))
print ("A exponenciação de n1 ** n2 é: ",int(n1 ** n2))
print("***************************************************************")
print("======================= Exercício 2 ==========================================================")
# 2. Média de Notas
# Peça ao usuário três notas e calcule a média delas.
# 📌 Fórmula:
# Média = nota1+nota2+nota3 / 3
nota1 = float(input("Digite a primeira nota: ",))
nota2 = float(input("Digite a segunda nota: ",))
nota3 = float(input("Digite a terceira nota: ",))
Média = (nota1+nota2+nota3)/3
print(" A média calculada foi: ",Média)
print("***************************************************************")
print("======================= Exercício 3 ==========================================================")
# Crie um programa que peça o raio de um círculo e calcule
# sua área.
# 📌 Fórmula: área = π×raio2
# 📌 Dica: Use import math e math.pi.
import math
circ = float(input("Informe o raio de um círculo: "))
area = math.pi*(circ**2)
print ("A área do círculo calculada é de: ",format(area, ".2f"))
print("***************************************************************")
print("======================= Exercício 4 ==========================================================")
# 4. Conversão de Temperatura
# Crie um programa que converta graus Celsius para
# Fahrenheit.
# Fórmula: (C x 9/5) +32
Cels = (float(input("Digite a temperatura em Celsius: ")))
Far = (Cels * 9/5) + 32
print( "A temperatura de ",Cels,"ºC é igual a ",Far,"ºF")
print("***************************************************************")
print("======================= Exercício 5 ==========================================================")
# 5. Calculadora de Desconto
# Crie um programa que peça o preço de um produto e o percentual de desconto aplicado.
# O programa deve calcular o preço final do produto
# A fórmula é:
# Preço final = Preço original - (Preço Original x (Desconto/100))
preco = float(input("Informe o preço do produto: "))
desconto = float(input("Informe o valor do desconto: "))
preco_final = preco -(preco*(desconto/100))
print("O preco final do produto, com desconte é: ", format(preco_final, ".2f"))
print("***************************************************************")
print("======================= Exercício 6 ==========================================================")
# 6. Maior de Idade?
# Peça ao usuário sua idade e verifique se ele é maior
# de idade (18 anos ou mais).
idade = int(input("Digite sua idade: "))
if idade >= 18:
    print("Você é maior de idade.")
    print("***************************************************************")
else:
    print("Você é menor de idade.")
    print("***************************************************************")
print("======================= Exercício 7 ==========================================================")
# 7. Pode Acessar o Sistema?
# Crie um programa que verifique se um usuário pode
# acessar um sistema. O acesso só é permitido se:
# ✅ Ele for administrador OU tiver mais de 18 anos E
# tiver uma conta ativa

admin = bool(input("Você é administrador? (Sim/Não): "))
idade = int(input("Digite sua idade: "))
conta_ativa = bool(input("Sua conta está ativa? (Sim/Não): "))
if admin == True or (idade >= 18 and conta_ativa == True):
    print("Você pode acessar o sistema.")
else:
    print("Você não pode acessar o sistema.")
print("***************************************************************")
print("======================= Exercício 8 ==========================================================")
# 8. Número Par e Maior que 10?
# Peça ao usuário um número e verifique se ele é par e maior
# que 10 ao mesmo tempo.
# 📌 Dica: Um número é par quando numero % 2 == 0.
x = int(input("Digite um número inteiro: "))

x_par = x % 2 == 0
x_maior_que_10 = x > 10

# Relatório completo
if x_par:
    print("O número é par.")
else:
    print("O número não é par.")

if x_maior_que_10:
    print("O número é maior que 10.")
else:
    print("O número não é maior que 10.")
print("***************************************************************")
print("======================= Exercício 9 ==========================================================")
# 9. Pode Tirar Carteira de Motorista?
# O usuário pode tirar a carteira de motorista se:
# ✅ Tiver pelo menos 18 anos E não tiver problemas na documentação.
# 📌 Entrada: Perguntar a idade e se os documentos estão em dia (True ou False)
idade_nova = int(input("Informe sua idade: "))
documento = input(("Seus documentos estão em dia?"))
if idade_nova >= 18 and documento == True:
    print("Você pode tirar a carteira de motorista.")
else:
    print("Você não pode tirar a carteira de motorista.")
print("***************************************************************")
print("======================= Exercício 10 ==========================================================")
# 10. Promoção de Loja
# Uma loja está fazendo uma promoção onde os clientes ganham um brinde se:
# ✅ Gastarem mais de R$100 OU forem clientes VIP (True ou False)
# 📌 Entrada: Perguntar o valor gasto e se é cliente VIP.

vip = input("Você é cliente VIP? (Sim/Não): ").strip().lower()
compra = float(input("Informe quanto você gastou: "))

if (compra >= 100) or (vip == "sim"):
    print("Você ganhou um brinde.")
else:
    print("Você não ganhou nenhum brinde.")

print("***************************************************************")

# %%
# 8. Número Par e Maior que 10?
# Peça ao usuário um número e verifique se ele é par e maior
# que 10 ao mesmo tempo.
# 📌 Dica: Um número é par quando numero % 2 == 0.
x = int(input("Digite um número inteiro: "))

x_par = x % 2 == 0
x_maior_que_10 = x > 10

# Relatório completo
if x_par:
    print("O número é par.")
else:
    print("O número não é par.")

if x_maior_que_10:
    print("O número é maior que 10.")
else:
    print("O número não é maior que 10.")
print("***************************************************************")
print("======================= Exercício 9 ==========================================================")
# Out:
# Digite um número inteiro: 4
# O número é par.
# O número não é maior que 10.
# ***************************************************************
# ======================= Exercício 9 ==========================================================
