# %% [markdown]
# <a href="https://colab.research.google.com/github/HuelFra/phyton/blob/main/Matplotlib_banco_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando os pacotes
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfsalario = pd.read_csv("Salaries.csv")

# %%
dfsalario.head(2)

# %%
dfsalario = dfsalario[dfsalario["BasePay"] != "Not Provided"]

# %%
dfsalario["BasePay"] = dfsalario["BasePay"].astype(float)

# %%
dfsalario_plots = dfsalario[["BasePay","Year", "JobTitle"]]

# %%
dfsalario_plots
# Out:
#           BasePay  Year                                        JobTitle
# 0       167411.18  2011  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       155966.02  2011                 CAPTAIN III (POLICE DEPARTMENT)
# 2       212739.13  2011                 CAPTAIN III (POLICE DEPARTMENT)
# 3        77916.00  2011            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4       134401.60  2011    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...           ...   ...                                             ...
# 148645       0.00  2014                       Human Services Technician
# 148647       0.00  2014                     Communications Dispatcher 2
# 148648       0.00  2014                                       Custodian
# 148649       0.00  2014                                       Custodian
# 148653       0.00  2014                      Counselor, Log Cabin Ranch
#
# [148650 rows x 3 columns]

# %%
dfsalario_plots.groupby("Year").size()
# Out:
# Year
# 2011    36159
# 2012    36766
# 2013    37606
# 2014    38119
# dtype: int64

# %%
dfsalario_plots["Year"] = dfsalario_plots["Year"].astype(int)
qtd_por_ano = dfsalario_plots.groupby("Year").size()
# Out:
# <ipython-input-14-9b9fa92087c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsalario_plots["Year"] = dfsalario_plots["Year"].astype(int)

# %%
plt.figure(figsize=(10,5))
plt.bar(qtd_por_ano.index, qtd_por_ano.values)
plt.xlabel("Ano")
plt.ylabel("Quantidade")
plt.title("Quantidade de pessoas por ano")
plt.show()

# %%
media_salario = dfsalario_plots.groupby("Year")["BasePay"].mean()

# %%
plt.figure(figsize=(10,5))
plt.plot(media_salario.index, media_salario.values)
plt.xlabel("Ano")
plt.ylabel("Média do salário")
plt.title("Média do salário por ano")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(dfsalario_plots["BasePay"], dfsalario_plots["Year"])
ax.set_xlabel("Salário")
ax.set_ylabel("Ano")
# Out:
# Text(0, 0.5, 'Ano')

# %%
#
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
ax1.bar(qtd_por_ano.index, qtd_por_ano.values, color='green')
ax1.set_title('Quantidade de Registros por Ano')
ax1.set_xlabel('Ano')
ax1.set_ylabel('Quantidade')
ax2.plot(media_salario.index, media_salario.values, marker='o')
ax2.set_title('Média Salarial por Ano')
ax2.set_xlabel('Ano')
ax2.set_ylabel('Média Salarial')
plt.tight_layout()
plt.show()

# %%
dfsalario_plots.boxplot(column='BasePay', by='Year', grid=True)
plt.title('Distribuição dos Salários por Ano')
plt.xlabel('Ano')
plt.ylabel('Salário Base')
plt.show()

# %%
media_salario.plot(kind='barh', figsize=(8,5))
plt.title('Média Salarial por Ano')
plt.xlabel('Média Salarial')
plt.ylabel('Ano')
plt.show()
