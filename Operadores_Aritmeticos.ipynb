# %% [markdown]
# <a href="https://colab.research.google.com/github/HuelFra/phyton/blob/main/Operadores_Aritmeticos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('Olá' + ' mundo!')
print()
print('Olá '*5)
print()
print('-------------------')
print('     Bem Vindo     ')
print('-------------------')
print()
print('-'*21)
print('-' *6 + 'Bem Vindo' + '-'*4)
print('-'*21)
print()
print('A operação: 7 + 2 * 4 =', (7 + 2 * 4),('é diferente'),'da operação: (7 + 2) * 4 =',((7 + 2)* 4))
print()
print('-'*20 + ' Convertendo variáveis ' + '-'*20)
print()
print(('-'*10 + 'Convertendo 1.857 para int' + '-'*10),int(1.857))
print(('-'*10 + 'Convertendo 4 para int' + '-'*10),int('4'))
print(('-'*10 + 'Convertendo True para int' + '-'*10),int(True))
print(('-'*10 + 'Convertendo False para int' + '-'*10),int(False))
print(('-'*10 + 'Convertendo text34 para int' + '-'*10),'Gera erro porque inteiro não aceita conversão direta para string')
print('-'*65)
print()
print(('-'*10 + 'Convertendo 1 para float' + '-'*10),float(1))
print(('-'*10 + 'Convertendo 4 para float' + '-'*10),float('4'))
print(('-'*10 + 'Convertendo True para float' + '-'*10),float(True))
print(('-'*10 + 'Convertendo False para float' + '-'*10),float(False))
print(('-'*10 + 'Convertendo text34 para float' + '-'*10),'Gera erro porque float não aceita conversão direta para string')
print('-'*65)
print()
print(('-'*10 + 'Convertendo 1 para string' + '-'*10),str(1))
print(('-'*10 + 'Convertendo 2.758 para string' + '-'*10),str(2.758))
print(('-'*10 + 'Convertendo True para string' + '-'*10),str(True)) # O retorno passa a ser uma palavra e não fará mais o papel comparativo
print(('-'*10 + 'Convertendo False para string' + '-'*10),str(False))# O retorno passa a ser uma palavra e não fará mais o papel comparativo
print('-'*65)
print()
print('-'*20 + ' Melhorando o código de pedido de lanche ' + '-'*20)
print()
lanchepreco = float(input('Qual o valor do lanche?'))
batatapreco = float(input('Qual o valor da batata?'))
pedidoValorTotal = lanchepreco + batatapreco
print('Você pediu um lanche de R${} e uma batata de R${}, totalizando:R${}'.format (lanchepreco, batatapreco, pedidoValorTotal))
print('-'*65)
print()
print('-'*20 + ' Exemplo usando format ' + '-'*20)
a=2
b=3
print('Texto {}, mais texto {}'.format (a,b))
# Explicação: Quando usamos print com format, considera-se tudo dentro de uma mesma string (parte textual e parte do conteúdo).
# As {} são também chamadas de máscaras. Devem ser usadas onde serão inseridas as veriáveis.
# O format é o método. Separa as variáveis que estão dentro do print.
print('-'*65)
print()
print('-'*20 + ' Aprendendo a delimitar o número de casas decimais ' + '-'*20)
print()
#Dentro de um método podemos informar como queremos que a variável apareça
print ('-'*20 + 'Sem delimitar o número de casa decimais' + '-'*20 )
a = 1
b = 7
print('a dividido por b é: {}'.format (a/b))
print ()
print ('-'*20 + 'Delimitando o número de casa decimais' + '-'*20 )
a = 1
b = 7
print('a dividido por b é: {:.5f}'. format (a/b))
print('-'*65)
print()
print('-'*20 + 'Entendendo a estrutura de Máscara' + '-'*20 )
print()
a= 245
b = 2.835895
print('|{0:10d}| e {1:10.4f}|'.format(a,b))
# {0:10d} = O 0 representa a posição que irá aparecer dentro do format. Lembrando que o primeiro índice é sempre 0.
# Nesse caso a primeira coisa que aparecerá dentro do format é o a. O a ocupará a primeira {}. Depois vem os :
# A partir dos :, mostramos as características que eu quero daquele número, daquela variável.
# Seria: 0 --> primeira variável do format; : --> é o separador; 10 --> separar 10 espaços para o número e d --> número inteiro
#{1:10.4f} = Seria: 1 --> 2ª variável no format; : --> é o separados; 10 --> separar 10 espaços para o número e 4f --> limitar em 4 floats (algarismos após a vírgula)
# Out:
# Olá mundo!
#
# Olá Olá Olá Olá Olá
#
# -------------------
#      Bem Vindo
# -------------------
#
# ---------------------
# ------Bem Vindo----
# ---------------------
#
# A operação: 7 + 2 * 4 = 15 é diferente da operação: (7 + 2) * 4 = 36
#
# -------------------- Convertendo variáveis --------------------
#
# ----------Convertendo 1.857 para int---------- 1
# ----------Convertendo 4 para int---------- 4
# ----------Convertendo True para int---------- 1
# ----------Convertendo False para int---------- 0
# ----------Convertendo text34 para int---------- Gera erro porque inteiro não aceita conversão direta para string
# -----------------------------------------------------------------
#
# ----------Convertendo 1 para float---------- 1.0
# ----------Convertendo 4 para float---------- 4.0
# ----------Convertendo True para float---------- 1.0
# ----------Convertendo False para float---------- 0.0
# ...
